# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
import requests
import os
import pandas as pd 
import pprint
import pymongo
import matplotlib
import json

from flask import (
    Flask,
    render_template,
    jsonify)

# %%
df = pd.read_excel('top10list.xlsx', index_col=0)
df
# Out:
#                              2009     2010     2011     2012     2013  \
# Park
# Acadia NP                 2227698  2504208  2374645  2431052  2254922
# Glacier NP                2031348  2200048  1853564  2162035  2190374
# Grand Canyon NP           4348068  4388386  4298178  4421352  4564840
# Grand Teton NP            2580081  2669374  2587437  2705256  2688794
# Great Smoky Mountains NP  9491437  9463538  9008830  9685829  9354695
# Olympic NP                3276459  2844563  2966502  2824908  3085340
# Rocky Mountain NP         2822325  2955821  3176941  3229617  2991141
# Yellowstone NP            3295187  3640185  3394326  3447729  3188030
# Yosemite NP               3737472  3901408  3951393  3853404  3691191
# Zion NP                   2735402  2665972  2825505  2973607  2807387
#
#                               2014      2015      2016      2017      2018  \
# Park
# Acadia NP                  2563129   2811184   3303393   3509271   3537575
# ...
