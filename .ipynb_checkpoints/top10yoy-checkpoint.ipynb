# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
import requests
import os
import pandas as pd 
import pprint
import pymongo
import matplotlib

# %%
url = 'https://irma.nps.gov/Stats/SSRSReports/National%20Reports/Annual%20Visitation%20By%20Park%20(1979%20-%20Last%20Calendar%20Year)'
browser = Browser('chrome')
browser.visit(url)
html = browser.html

# %%
##conn = 'mongodb://localhost:27017'

##client = pymongo.MongoClient(conn)
##db = client.top10yoy_db

# %%
visitnumbers = pd.read_excel('AnnualVisitation.xlsx', index_col=0)
visitnumbers
# Out:
#                                       Recreational Visits  Unnamed: 1  \
# Park Name                                          2009.0      2010.0
# Abraham Lincoln Birthplace NHP                   221111.0    177122.0
# Acadia NP                                       2227698.0   2504208.0
# Adams NHP                                        253656.0     73339.0
# African Burial Ground NM                              NaN    117113.0
# Agate Fossil Beds NM                              12694.0     12509.0
# Alibates Flint Quarries NM                         2918.0      4350.0
# Allegheny Portage Railroad NHS                   118931.0    107363.0
# Amistad NRA                                     2573966.0   1574322.0
# Andersonville NHS                                136267.0    121535.0
# Andrew Johnson NHS                                63296.0     60323.0
# Aniakchak NM & PRES                                  14.0        62.0
# ...

# %%
visitnumbers.loc[['Grand Canyon NP', 'Rocky Mountain NP']]
# Out:
#                    Recreational Visits  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# Grand Canyon NP              4348068.0   4388386.0   4298178.0   4421352.0
# Rocky Mountain NP            2822325.0   2955821.0   3176941.0   3229617.0
#
#                    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# Grand Canyon NP     4564840.0   4756771.0   5520736.0   5969811.0     6254238
# Rocky Mountain NP   2991141.0   3434751.0   4155916.0   4517585.0     4437215
#
#                    Unnamed: 9  Unnamed: 10
# Grand Canyon NP       6380495  5.09029e+06
# Rocky Mountain NP     4590493  3.63118e+06
